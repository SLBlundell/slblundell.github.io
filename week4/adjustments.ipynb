# %%
# import necessary libraries
import pandas as pd
import os
import glob

# %%
cpi = pd.read_csv('C:/Users/whisk/OneDrive/Documents/Bristol/Economics/Year 4/Data Science/slblundell.github.io/nba_project/data/cpi-u_2013-22.csv')
bri = pd.read_csv('C:/Users/whisk/OneDrive/Documents/Bristol/Economics/Year 4/Data Science/slblundell.github.io/nba_project/data/total_league_revenues.csv')

# %%
teams = ['atl', 'bkn', 'bos', 'cha', 'chi', 'cle', 'dal', 'den', 'det', 'gsw', 'hou', 'ind', 'lac', 'lal', 'mem', 
'mia', 'mil', 'min', 'nop', 'nyk', 'okc', 'orl', 'phi', 'phx', 'por', 'sac', 'sas', 'tor', 'uth', 'was']

# %%
for team in teams:
    df = pd.read_csv(f'active_payroll_{team}.csv')
    
    df = df.rename(columns={'year': 'Year', 'team': 'Team', 'code': 'Code','active': 'Payroll'})
    
    df = pd.merge(df, cpi, on='Year')
    df = pd.merge(df, bri, on='Year')

    df['Adjusted_Payroll'] = df['Payroll'] / (df['Annual'] + df['Index'])

    df.to_csv(f'active_payroll_{team}.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\whisk\OneDrive\Documents\Bristol\Economics\Year 4\Data Science\slblundell.github.io\week4\adjustments.ipynb Cell 4 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/whisk/OneDrive/Documents/Bristol/Economics/Year%204/Data%20Science/slblundell.github.io/week4/adjustments.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df = pd.read_csv(f'active_payroll_{team}.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/whisk/OneDrive/Documents/Bristol/Economics/Year%204/Data%20Science/slblundell.github.io/week4/adjustments.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> df = df.rename(columns={'year': 'Year', 'team': 'Team', 'code': 'Code','active': 'Payroll'})
# ----> <a href='vscode-notebook-cell:/c%3A/Users/whisk/OneDrive/Documents/Bristol/Economics/Year%204/Data%20Science/slblundell.github.io/week4/adjustments.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> df = pd.merge(df, cpi, on='Year')
#       <a href='vscode-notebook-cell:/c%3A/Users/whisk/OneDrive/Documents/Bristol/Economics/Year%204/Data%20Science/slblundell.github.io/week4/adjustments.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> df = pd.merge(df, bri, on='Year')
#       <a href='vscode-notebook-cell:/c%3A/Users/whisk/OneDrive/Documents/Bristol/Economics/Year%204/Data%20Science/slblundell.github.io/week4/adjustments.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> df['Adjusted Payroll'] = df['Payroll'] / (df['Annual'] + df['Index'])
#
# File c:\Users\whisk\miniconda3\envs\myenv\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File c:\Users\whisk\miniconda3\envs\myenv\lib\site-packages\pandas\core\reshape\merge.py:700, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     693 self._cross = cross_col
#     695 # note this function has side effects
#     696 (
#     697     self.left_join_keys,
#     698     self.right_join_keys,
#     699     self.join_names,
# --> 700 ) = self._get_merge_keys()
#     702 # validate the merge keys dtypes. We may need to coerce
#     703 # to avoid incompatible dtypes
#     704 self._maybe_coerce_merge_keys()
#
# File c:\Users\whisk\miniconda3\envs\myenv\lib\site-packages\pandas\core\reshape\merge.py:1110, in _MergeOperation._get_merge_keys(self)
#    1108     right_keys.append(rk)
#    1109 if lk is not None:
# -> 1110     left_keys.append(left._get_label_or_level_values(lk))
#    1111     join_names.append(lk)
#    1112 else:
#    1113     # work-around for merge_asof(left_index=True)
#
# File c:\Users\whisk\miniconda3\envs\myenv\lib\site-packages\pandas\core\generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'Year'

# %%
df
# Out:
#                                                                                                                                <<<<<<< HEAD
# NaN                                                Unnamed: 0    Team          Code Year      Payroll   Annual  Revenue    Adjusted_Payroll
# 0                                                  0             Atlanta Hawks ATL  2021      132777480 270.97  641.0    145594.13138590084
# 1                                                  1             Atlanta Hawks ATL  2020      115950371 258.811 792.0    110343.69739182404
# 2                                                  2             Atlanta Hawks ATL  2019      82491624  255.657 876.0     72894.54666917627
# 3                                                  3             Atlanta Hawks ATL  2018      62166838  251.107 801.0     59087.94257618284
# 4                                                  4             Atlanta Hawks ATL  2017      67426026  245.12  737.0     68653.55150083493
# 5                                                  5             Atlanta Hawks ATL  2016      92928845  240.007 587.0    112367.66436076116
# 6                                                  6             Atlanta Hawks ATL  2015      71332945  237.017 518.0     94478.59452171274
# 7                                                  7             Atlanta Hawks ATL  2014      57245276  236.736 479.0      79980.9929918294
# 8                                                  8             Atlanta Hawks ATL  2013      55517146  232.957 456.0     80581.43831908233
# 9                                                  9             Atlanta Hawks ATL  2012      63620146  229.594 368.0    106460.48320431595
# 10                                                 10            Atlanta Hawks ATL  2011      71583096  224.939 396.0    115282.00998809868
# =======                                            NaN           NaN           NaN  NaN       NaN       NaN     NaN                     NaN
# NaN                                                team          code          year active    NaN       NaN     NaN                     NaN
# 14                                                 Atlanta Hawks ATL           2022 148480277 NaN       NaN     NaN                     NaN
# 47                                                 Atlanta Hawks ATL           2021 132777480 NaN       NaN     NaN                     NaN
# 83                                                 Atlanta Hawks ATL           2020 115950371 NaN       NaN     NaN                     NaN
# 118                                                Atlanta Hawks ATL           2019 82491624  NaN       NaN     NaN                     NaN
# 148                                                Atlanta Hawks ATL           2018 62166838  NaN       NaN     NaN                     NaN
# 171                                                Atlanta Hawks ATL           2017 67426026  NaN       NaN     NaN                     NaN
# 194                                                Atlanta Hawks ATL           2016 92928845  NaN       NaN     NaN                     NaN
# 232                                                Atlanta Hawks ATL           2015 71332945  NaN       NaN     NaN                     NaN
# 265                                                Atlanta Hawks ATL           2014 57245276  NaN       NaN     NaN                     NaN
# 294                                                Atlanta Hawks ATL           2013 55517146  NaN       NaN     NaN                     NaN
# 314                                                Atlanta Hawks ATL           2012 63620146  NaN       NaN     NaN                     NaN
# 335                                                Atlanta Hawks ATL           2011 71583096  NaN       NaN     NaN                     NaN
# >>>>>>> parent of 8e615ed (Updated team payroll... NaN           NaN           NaN  NaN       NaN       NaN     NaN                     NaN
